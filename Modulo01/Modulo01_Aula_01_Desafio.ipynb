# %% [markdown]
# <a href="https://colab.research.google.com/github/BrSiqueira/BootcampDataScience2/blob/main/Modulo01/Modulo01_Aula_01_Desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

dados = pd.read_csv("/content/A155231189_28_143_208.csv", encoding="ISO-8859-1", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=',')
pd.options.display.float_format = "{:.2f}".format
dados
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
#       Unidade da Federação    2008/Jan  ...     2021/Mar          Total
# 0              11 Rondônia  1388528.39  ...  11023309.47   996411254.68
# 1                  12 Acre   902416.00  ...   4077045.92   450048530.47
# 2              13 Amazonas  4735529.42  ...  22032176.22  1917247936.05
# 3               14 Roraima   657889.53  ...   3985530.08   328876965.09
# 4                  15 Pará 18864744.11  ...  33276392.89  4705309002.29
# 5                 16 Amapá  1120973.34  ...   3188210.98   309860092.59
# 6             17 Tocantins  3441592.69  ...   1357751.33  1020028272.64
# 7              21 Maranhão 10723506.39  ...  39663677.48  3871069498.04
# 8                 22 Piauí  7985142.43  ...  20018325.75  2280888802.74
# 9                 23 Ceará 15539821.90  ...  62079618.54  6591836650.18
# 10  24 Rio Grande do Norte  5947814.08  ...  23306498.68  2660122027.15
# 11              25 Paraíba 10723002.45  ...  25750897.89  2614919044.63
# 12           26 Pernambuco 14393949.89  ...  83870992.73  8581189975.91
# 13              27 Alagoas  6243726.32  ...  22118639.05  2236415402.51
# 14              28 Sergipe  2780750.11  ...  13321494.41  1215853015.00
# 15                29 Bahia 21211522.47  ...  98746333.07  9791541570.52
# 16         31 Minas Gerais 45671659.76  ... 200471045.07 20418737536.66
# 17       32 Espírito Santo  5456723.98  ...  45490499.45  3405850698.58
# 18       33 Rio de Janeiro 23025258.52  ... 106837295.81 10337391164.52
# 19            35 São Paulo 91678473.48  ... 392946147.42 41396604304.13
# 20               41 Paraná 38266347.46  ... 140264608.52 14681514706.67
# 21       42 Santa Catarina 16504913.45  ...  81376630.57  7835011163.40
# 22    43 Rio Grande do Sul 30931325.46  ... 130155185.16 12764391179.92
# 23   50 Mato Grosso do Sul  5377392.11  ...  25168195.34  2324525096.33
# 24          51 Mato Grosso  4795299.01  ...  19611032.61  2180119781.15
# 25                52 Goiás 15310637.29  ...  45592686.49  4973573613.47
# 26     53 Distrito Federal  4745919.19  ...  31831917.45  2592422853.56
#
# [27 rows x 161 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 161 entries, Unidade da Federação to Total
# dtypes: float64(159), object(2)
# memory usage: 34.1+ KB

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Dez     53377763.15
# 2021/Jan     56073748.02
# 2021/Fev     55578233.31
# 2021/Mar     62502301.42
# Total      6388213338.48
# Length: 159, dtype: float64

# %% [markdown]
# ## Desafio 1: Selecionar os dados da coluna 2008/Jan?

# %%
dados["2008/Jan"]
# Out:
# 0     1388528.39
# 1      902416.00
# 2     4735529.42
# 3      657889.53
# 4    18864744.11
# 5     1120973.34
# 6     3441592.69
# 7    10723506.39
# 8     7985142.43
# 9    15539821.90
# 10    5947814.08
# 11   10723002.45
# 12   14393949.89
# 13    6243726.32
# 14    2780750.11
# 15   21211522.47
# 16   45671659.76
# 17    5456723.98
# 18   23025258.52
# 19   91678473.48
# 20   38266347.46
# 21   16504913.45
# 22   30931325.46
# 23    5377392.11
# 24    4795299.01
# 25   15310637.29
# 26    4745919.19
# Name: 2008/Jan, dtype: float64

# %%
dados[["Unidade da Federação","2008/Jan"]]
# Out:
#       Unidade da Federação    2008/Jan
# 0              11 Rondônia  1388528.39
# 1                  12 Acre   902416.00
# 2              13 Amazonas  4735529.42
# 3               14 Roraima   657889.53
# 4                  15 Pará 18864744.11
# 5                 16 Amapá  1120973.34
# 6             17 Tocantins  3441592.69
# 7              21 Maranhão 10723506.39
# 8                 22 Piauí  7985142.43
# 9                 23 Ceará 15539821.90
# 10  24 Rio Grande do Norte  5947814.08
# 11              25 Paraíba 10723002.45
# 12           26 Pernambuco 14393949.89
# 13              27 Alagoas  6243726.32
# 14              28 Sergipe  2780750.11
# 15                29 Bahia 21211522.47
# 16         31 Minas Gerais 45671659.76
# 17       32 Espírito Santo  5456723.98
# 18       33 Rio de Janeiro 23025258.52
# 19            35 São Paulo 91678473.48
# 20               41 Paraná 38266347.46
# 21       42 Santa Catarina 16504913.45
# 22    43 Rio Grande do Sul 30931325.46
# 23   50 Mato Grosso do Sul  5377392.11
# 24          51 Mato Grosso  4795299.01
# 25                52 Goiás 15310637.29
# 26     53 Distrito Federal  4745919.19

# %%
dados["2008/Ago"].sum()
# Out:
# 750608648.28

# %%
dados["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %% [markdown]
# ## Aula 01, Pate 2

# %% [markdown]
# ### Desafio 1: Melhorar o título do gráfico

# %%
import matplotlib.ticker as ticker
ax = dados.plot(x="Unidade da Federação", y=["2008/Ago", "2009/Ago"], kind="bar", figsize=(18,8))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Comparação dos gastos de 2008 e 2009')
plt.show()

# %%
ax = dados.plot(x="Unidade da Federação", y=[ "2019/Mar", "2020/Mar", "2021/Mar"], kind="bar", figsize=(18,8))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Comparação dos Meses mais recentes')
plt.show()
